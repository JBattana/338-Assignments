# %% [markdown]
# <a href="https://colab.research.google.com/github/JBattana/338-Assignments/blob/main/338_Assignment_5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target_names[iris.target]

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# 1. How do the distributions of sepal length vary among different species of iris flowers?
#
#
# Analyze the distributions using descriptive statistics - mean, median, standard deviation and visualize data using box plots/ histograms to identify any differences in the spread of sepal length data across species.

# %%
# code here

# %% [markdown]
# 2. What is the correlation between petal length and petal width in iris flowers?
#
# Calculate the Pearson correlation coefficient to check the relationship between petal length and petal width.

# %%
# code here

# %% [markdown]
# 3. Are there any outliers in the sepal width measurements for a specific species of iris flowers?
#
# Use z-scores to identify any observations that fall outside the expected range of values for sepal width within each species.

# %%
# code here
